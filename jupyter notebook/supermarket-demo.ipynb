# %%
import os
os.listdir()
# Out:
# ['.DS_Store',
#  'supermarkets.json',
#  'Testing.ipynb',
#  'supermarket-demo.ipynb',
#  'supermarkets.csv',
#  'data.csv',
#  'supermarkets-semi-colons.txt',
#  'supermarkets.xlsx',
#  '.ipynb_checkpoints',
#  'supermarkets-commas.txt']

# %%
import pandas

# %%
df_csv = pandas.read_csv("supermarkets.csv")
df_csv
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df_json = pandas.read_json("supermarkets.json")
df_json
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df_excel = pandas.read_excel("supermarkets.xlsx", sheet_name = 0)
df_excel
# Out:
#    ID          Address           City             State Country  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA
# 1   2   735 Dolores St  San Francisco          CA 94119     USA
# 2   3      332 Hill St  San Francisco  California 94114     USA
# 3   4     3995 23rd St  San Francisco          CA 94114     USA
# 4   5  1056 Sanchez St  San Francisco        California     USA
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA
#
#   Supermarket Name  Number of Employees
# 0          Madeira                    8
# 1      Bready Shop                   15
# 2      Super River                   25
# 3       Ben's Shop                   10
# 4          Sanchez                   12
# 5       Richvalley                   20

# %%
df_txt = pandas.read_csv("supermarkets-commas.txt")
df_txt
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df_txt2 = pandas.read_csv("supermarkets-semi-colons.txt", sep = ';')
df_txt2
# Out:
#    ID          Address           City             State Country          Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA       Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA   Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA       Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df8 = pandas.read_csv("data.csv", header = None)
df8.columns = ["ID", "Address", "City", "State/Zip", "Country", "Name", "Employees"]
df8 = df8.set_index("Address")
list(df8.loc[:,"Country"]) #second param included
# Out:
# ['USA', 'USA', 'USA', 'USA', 'USA', 'USA']

# %%
df8.iloc[1:3, 1:3] #second param not included
# Out:
#                          City         State/Zip
# Address
# 735 Dolores St  San Francisco          CA 94119
# 332 Hill St     San Francisco  California 94114

# %%
#df8 = df8.drop("3666 21st St", 0)
#df8 = df8.drop("Country", 1)
#df8 = df8.drop(df8.columns[0:3], 1)
df8
# Out:
#                         Name  Employees
# Address
# 735 Dolores St   Bready Shop         15
# 332 Hill St      Super River         25
# 3995 23rd St      Ben's Shop         10
# 1056 Sanchez St      Sanchez         12
# 551 Alvarado St   Richvalley         20

# %%
df8["Continent"] = df8.shape[0] * ["North America"] #.shape returns len(rows) which would be 5
df8
# Out:
#                         Name  Employees      Continent
# Address
# 735 Dolores St   Bready Shop         15  North America
# 332 Hill St      Super River         25  North America
# 3995 23rd St      Ben's Shop         10  North America
# 1056 Sanchez St      Sanchez         12  North America
# 551 Alvarado St   Richvalley         20  North America

# %%
df8_t = df8.T #get translation
df8_t["My Address"] = ["My Name", 10, "North America"] #make a column
df8 = df8_t.T #translate back (column --> row)
df8
# Out:
#                         Name Employees      Continent
# Address
# 735 Dolores St   Bready Shop        15  North America
# 332 Hill St      Super River        25  North America
# 3995 23rd St      Ben's Shop        10  North America
# 1056 Sanchez St      Sanchez        12  North America
# 551 Alvarado St   Richvalley        20  North America
# My Address           My Name        10  North America

# %%
df9 = pandas.read_csv("supermarkets.csv")
df9
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
from geopy.geocoders import ArcGIS
import ssl
import geopy.geocoders
nom = ArcGIS()
ctx = ssl.create_default_context()
ctx.check_hostname = False
ctx.verify_mode = ssl.CERT_NONE
geopy.geocoders.options.default_ssl_context = ctx
nom.geocode("2018 Trousdale Dr, Burlingame, CA 94010")
# Out:
# Location(2018 Trousdale Dr, Burlingame, California, 94010, (37.59150600000001, -122.3879805, 0.0))

# %%
df9["Address"] = df9["Address"] + ", " + df9["City"] + ", " + df9["State"] + ", " + df9["Country"]
df9["Coordinates"] = df9["Address"].apply(nom.geocode)
# Out:
# ---------------------------------------------------------------------------
# GeocoderServiceError                      Traceback (most recent call last)
# <ipython-input-20-6b9fd298e571> in <module>
#       1 df9["Address"] = df9["Address"] + ", " + df9["City"] + ", " + df9["State"] + ", " + df9["Country"]
# ----> 2 df9["Coordinates"] = df9["Address"].apply(nom.geocode)
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    3846             else:
#    3847                 values = self.astype(object).values
# -> 3848                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3849
#    3850         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# ...
